# %%
import numpy as np

# %%
r = 20
for i in range(16):
    print(f"Halbach #{i+1}")
    print(f"{r*np.cos(2*np.pi*(i/16)):3.4f}")
    print(f"{r*np.sin(2*np.pi*(i/16)):3.4f}")
    print()
# Out:
# Halbach #1
# 20.0000
# 0.0000
#
# Halbach #2
# 18.4776
# 7.6537
#
# Halbach #3
# 14.1421
# 14.1421
#
# Halbach #4
# 7.6537
# 18.4776
#
# Halbach #5
# 0.0000
# 20.0000
#
# Halbach #6
# -7.6537
# 18.4776
#
# Halbach #7
# -14.1421
# 14.1421
#
# Halbach #8
# -18.4776
# 7.6537
#
# Halbach #9
# -20.0000
# 0.0000
#
# Halbach #10
# -18.4776
# -7.6537
#
# Halbach #11
# -14.1421
# -14.1421
#
# Halbach #12
# -7.6537
# -18.4776
#
# Halbach #13
# -0.0000
# -20.0000
#
# Halbach #14
# 7.6537
# -18.4776
#
# Halbach #15
# 14.1421
# -14.1421
#
# Halbach #16
# 18.4776
# -7.6537
