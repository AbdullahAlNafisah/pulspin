# %%
import serial.tools.list_ports

ports = list(serial.tools.list_ports.comports())
for p in ports:
    print(p.device, "-", p.description)
# Out:
# COM5 - Standard Serial over Bluetooth link (COM5)
# COM4 - Standard Serial over Bluetooth link (COM4)
# COM12 - USB-SERIAL CH340 (COM12)

# %%
from pyfirmata import Arduino

PORT = "COM12"
board = Arduino(PORT)
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# Cell In[3], line 4
#       1 from pyfirmata import Arduino
#       3 PORT = "COM12"
# ----> 4 board = Arduino(PORT)
#
# File c:\Users\abdul\Desktop\pulspin\.conda\Lib\site-packages\pyfirmata\__init__.py:19, in Arduino.__init__(self, *args, **kwargs)
#      17 args = list(args)
#      18 args.append(BOARDS['arduino'])
# ---> 19 super(Arduino, self).__init__(*args, **kwargs)
#
# File c:\Users\abdul\Desktop\pulspin\.conda\Lib\site-packages\pyfirmata\pyfirmata.py:89, in Board.__init__(self, port, layout, baudrate, name, timeout)
#      88 def __init__(self, port, layout=None, baudrate=57600, name=None, timeout=None):
# ---> 89     self.sp = serial.Serial(port, baudrate, timeout=timeout)
#      90     # Allow 5 secs for Arduino's auto-reset to happen
#      91     # Alas, Firmata blinks its version before printing it to serial
#      92     # For 2.3, even 5 seconds might not be enough.
#      93     # TODO Find a more reliable way to wait until the board is ready
#      94     self.pass_time(BOARD_SETUP_WAIT_TIME)
#
# File c:\Users\abdul\Desktop\pulspin\.conda\Lib\site-packages\serial\serialwin32.py:33, in Serial.__init__(self, *args, **kwargs)
#      31 self._overlapped_read = None
#      32 self._overlapped_write = None
# ---> 33 super(Serial, self).__init__(*args, **kwargs)
#
# File c:\Users\abdul\Desktop\pulspin\.conda\Lib\site-packages\serial\serialutil.py:244, in SerialBase.__init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     241     raise ValueError('unexpected keyword arguments: {!r}'.format(kwargs))
#     243 if port is not None:
# --> 244     self.open()
#
# File c:\Users\abdul\Desktop\pulspin\.conda\Lib\site-packages\serial\serialwin32.py:80, in Serial.open(self)
#      77 self._orgTimeouts = win32.COMMTIMEOUTS()
#      78 win32.GetCommTimeouts(self._port_handle, ctypes.byref(self._orgTimeouts))
# ---> 80 self._reconfigure_port()
#      82 # Clear buffers:
#      83 # Remove anything that was there
#      84 win32.PurgeComm(
#      85     self._port_handle,
#      86     win32.PURGE_TXCLEAR | win32.PURGE_TXABORT |
#      87     win32.PURGE_RXCLEAR | win32.PURGE_RXABORT)
#
# File c:\Users\abdul\Desktop\pulspin\.conda\Lib\site-packages\serial\serialwin32.py:222, in Serial._reconfigure_port(self)
#     219 comDCB.XoffChar = serial.XOFF
#     221 if not win32.SetCommState(self._port_handle, ctypes.byref(comDCB)):
# --> 222     raise SerialException(
#     223         'Cannot configure port, something went wrong. '
#     224         'Original message: {!r}'.format(ctypes.WinError()))
#
# SerialException: Cannot configure port, something went wrong. Original message: PermissionError(13, 'A device attached to the system is not functioning.', None, 31)
